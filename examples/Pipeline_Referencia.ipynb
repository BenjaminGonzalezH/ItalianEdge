# %% [markdown]
# # Pipeline de referencia
# El presente archivo esta dedicado a proporcionar una ruta de implementación de un pipeline de análisis de soluciones de agrupamiento con la finalidad de que esta sea vista
# dentro de la plataforma web
